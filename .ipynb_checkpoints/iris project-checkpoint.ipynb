# %% [markdown]
# # Iris Dataset plots and visualizations
#
# Classes:
#     1. Setosa
#     2. Virginica
#     3. Versicolor
#
# Attributes:
#     1. Sepal Length
#     2. Sepal Width
#     3. Petal Length
#     4. Petal Width

# %%
import numpy as n
import seaborn as sbs
import pandas as pd
import matplotlib.pyplot as plt
sbs.set(color_codes = True)
# %matplotlib inline

# %%
# loading dataset
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
# loading dataset through seaborn library directly
iris = sbs.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# plotting different curves for the dataset attributes
sbs.pairplot(iris, hue='species', size=3, aspect=1)
# Out:
# /home/deepak/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
iris.hist(edgecolor='black', linewidth=1, figsize=(12,8))
plt.show()

# %%
# loading dataset from scikit-learn (third method)
from  sklearn import  datasets

iris=datasets.load_iris()

x=iris.data
y=iris.target

# %%
# splitting
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.5)

# %%
# traing the model
from sklearn import tree

classifier=tree.DecisionTreeClassifier()
classifier.fit(x_train,y_train)

predictions=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_test,predictions))
# Out:
# 0.9466666666666667
